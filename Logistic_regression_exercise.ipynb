# %%
#Logistic_regression_exercise
#Xubin Lou
#31524742

# %%
import pandas as pd #import pandas
titanic_df=pd.read_excel('/Users/Carol/Desktop/titanic_data.xlsx') #read data from excel
titanic_df #show the data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
age_null=pd.isnull(titanic_df["Age"]) #pick up the lines where the Age is NaN
titanic_df[age_null].shape[0]
# Out:
# 177

# %%
titanic_df=titanic_df.dropna(subset=['Age']) #drop all the passengers from the dataset who miss the age information
titanic_df=titanic_df.reset_index(drop=True) #reorder the index of each row
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 709          886         0       3
# 710          887         0       2
# 711          888         1       1
# 712          890         1       1
# 713          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
X=titanic_df.drop(columns=['Name','Sex','Ticket','Cabin','Embarked','Survived','PassengerId'])
y=titanic_df['Survived']

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings("ignore")
logreg=LogisticRegression()
solvers = ['liblinear','lbfgs']
penalty = ['l1', 'l2']
c_values = [100, 10, 1.0, 0.1, 0.01]
param_grid = dict(solver=solvers,penalty=penalty,C=c_values)
cv=StratifiedShuffleSplit(n_splits=5, test_size=0.2, random_state=42)
grid=GridSearchCV(estimator=logreg, param_grid=param_grid, cv=cv, n_jobs=-1, verbose=2)
grid.fit(X,y)
print("The best parameters are %s with a score of %0.2f" %(grid.best_params_,grid.best_score_))
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# The best parameters are {'C': 1.0, 'penalty': 'l2', 'solver': 'liblinear'} with a score of 0.71

# %%
logreg=LogisticRegression()
solvers = ['liblinear','lbfgs']
penalty = ['l1', 'l2']
c_values = [20, 10, 1.0, 0.5, 0.1]
param_grid = dict(solver=solvers,penalty=penalty,C=c_values)
cv=StratifiedShuffleSplit(n_splits=5, test_size=0.2, random_state=42)
grid=GridSearchCV(estimator=logreg, param_grid=param_grid, cv=cv, n_jobs=-1, verbose=2)
grid.fit(X,y)
print("The best parameters are %s with a score of %0.2f" %(grid.best_params_,grid.best_score_))
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# The best parameters are {'C': 1.0, 'penalty': 'l2', 'solver': 'liblinear'} with a score of 0.71

# %%
logreg=LogisticRegression()
solvers = ['liblinear','lbfgs']
penalty = ['l1', 'l2']
c_values = [10, 5, 1.0, 0.5, 0.1]
param_grid = dict(solver=solvers,penalty=penalty,C=c_values)
cv=StratifiedShuffleSplit(n_splits=5, test_size=0.2, random_state=42)
grid=GridSearchCV(estimator=logreg, param_grid=param_grid, cv=cv, n_jobs=-1, verbose=2)
grid.fit(X,y)
print("The best parameters are %s with a score of %0.2f" %(grid.best_params_,grid.best_score_))
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# The best parameters are {'C': 1.0, 'penalty': 'l2', 'solver': 'liblinear'} with a score of 0.71

# %%
logreg=LogisticRegression()
solvers = ['liblinear','lbfgs']
penalty = ['l1','l2']
c_values = [4, 3, 1, 0.6, 0.3]
param_grid = dict(solver=solvers,penalty=penalty,C=c_values)
cv=StratifiedShuffleSplit(n_splits=5, test_size=0.2, random_state=42)
grid=GridSearchCV(estimator=logreg, param_grid=param_grid, cv=cv, n_jobs=-1, verbose=2)
grid.fit(X,y)
print("The best parameters are %s with a score of %0.2f" %(grid.best_params_,grid.best_score_))
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# The best parameters are {'C': 0.3, 'penalty': 'l1', 'solver': 'liblinear'} with a score of 0.72

# %%
logreg=LogisticRegression()
solvers = ['liblinear','lbfgs']
penalty = ['l1','l2']
c_values = [0.6, 0.4, 0.3, 0.2, 0.1]
param_grid = dict(solver=solvers,penalty=penalty,C=c_values)
cv=StratifiedShuffleSplit(n_splits=5, test_size=0.2, random_state=42)
grid=GridSearchCV(estimator=logreg, param_grid=param_grid, cv=cv, n_jobs=-1, verbose=2)
grid.fit(X,y)
print("The best parameters are %s with a score of %0.2f" %(grid.best_params_,grid.best_score_))
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# The best parameters are {'C': 0.4, 'penalty': 'l1', 'solver': 'liblinear'} with a score of 0.72
# /Users/carol/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/carol/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/carol/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/Users/carol/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 443, in _check_solver
# ...

# %%
logreg=LogisticRegression()
solvers = ['liblinear','lbfgs']
penalty = ['l1','l2']
c_values = [0.5, 0.4, 0.35, 0.3, 0.2]
param_grid = dict(solver=solvers,penalty=penalty,C=c_values)
cv=StratifiedShuffleSplit(n_splits=5, test_size=0.2, random_state=42)
grid=GridSearchCV(estimator=logreg, param_grid=param_grid, cv=cv, n_jobs=-1, verbose=2)
grid.fit(X,y)
print("The best parameters are %s with a score of %0.2f" %(grid.best_params_,grid.best_score_))
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# The best parameters are {'C': 0.4, 'penalty': 'l1', 'solver': 'liblinear'} with a score of 0.72
# /Users/carol/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/carol/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/carol/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 1306, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/Users/carol/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py", line 443, in _check_solver
# ...

# %%
#The best parameters are {'C': 0.4, 'penalty': 'l1', 'solver': 'liblinear'} with a score of 0.72

# %%
#The total number of model I trained is (2*2*5)*6=120, which is larger than 100.

# %%
#I updated the param_grid by shorten the C-value range each time to make it more centered to the best parameter of C-value I got from the previous trial.

# %%
#C means the inverse of the regularization strength. The stronger the regularization (and thus the smaller C is), the smaller the coefficients in the model will be and for lasso the fewer the coefficients it will have. Shrinking the coefficients too much or eliminating too many variables can weaken the model so how much regularization is needed is determined here using cross-validation.

# %%
#The penalty refers to regularization penalties that shrink or eliminate variable-coefficients in the model. The l1 penalty refers to lasso regularization which causes some of the feature-variable coefficients to go to 0 if they don’t contribute as much to the model as the other, more significant variables. The l2 penalty refers to ridge regression which shrinks the coefficients but never pushes them all the way to 0. Since lasso regularization simplifies the model it might seem that it would be preferable, but it will only outperform ridge regression if there are differences in how much the variables contribute. If all the variables contribute equally to the model, then ridge regression will outperform the lasso

# %%
#With n_jobs=-1, it uses 100% of the cpu of one of the cores. Each process is run in a different core. n_jobs is an integer, specifying the maximum number of concurrently running workers. If 1 is given, no joblib parallelism is used at all, which is useful for debugging. If set to -1, all CPUs are used.
